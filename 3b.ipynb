# %%
import sys
import json
import csv
import os

import pandas as pd
import numpy as np

# import matplotlib as mpl

# useful for printing dict and list objects
import pprint

import time
from datetime import datetime

import psycopg2
from sqlalchemy import create_engine, text as sql_text
import psycopg2.extras
from dotenv import load_dotenv

# %%
load_dotenv()

#get user input
db_username = os.environ['db_username']
db_password = os.environ['db_password']
                             
db_eng = create_engine('postgresql+psycopg2://' + db_username + ':' + db_password + '@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('public')},
                       isolation_level = 'SERIALIZABLE')

print("Successfully created db engine.")
# Out:
# Successfully created db engine.

# %%
filename = 'Step3b.json'

if os.path.exists(filename):
    try:
        # delete the file
        os.remove(filename)
        print(f"File '{filename}' successfully deleted.")
    except Exception as e:
        print(f"Error deleting file '{filename}': {e}")
else:
    print(f"File '{filename}' not found.")

#write perf data to file
def write_perf_data(new_data):
    
    #if file exists, read old data
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                old_data = json.load(f)  
            except json.JSONDecodeError:
                old_data = []  
    else:
        old_data = []

    # combine old and new data
    if isinstance(old_data, list):
        old_data.append(new_data)  
    else:
        old_data = [old_data, new_data]

    # write to file
    with open(filename, 'w') as f:
        json.dump(old_data, f, indent=4)

    print("wrote in file successfully")
# Out:
# File 'Step3b.json' not found.

# %%
# function to get the query for the year
def no_index_query(year, word):
    year_str = str(year)
    start_date = f"{year_str}-01-01"
    end_date = f"{year_str}-12-31"
    
    query = f"""
    SELECT count(*) 
    FROM reviews r 
    WHERE comments ILIKE '%{word}%'
      AND datetime >= '{start_date}'
      AND datetime <= '{end_date}';
    """
    
    return query

def index_query(year, word):
    year_str = str(year)
    start_date = f"{year_str}-01-01"
    end_date = f"{year_str}-12-31"
    
    query = f"""
    SELECT count(*) 
    FROM reviews r 
    WHERE comments_tsv @@ to_tsquery('{word}')
      AND datetime >= '{start_date}'
      AND datetime <= '{end_date}';
    """
    
    return query

#run time
n=3

# %% [markdown]
# ### Using the index comments_tsv_in_reviews VS. Not using an index and doing searches in the comments field
#
# ### Using or not using the index datetime in reviews

# %% [markdown]
# The 4 index combinations are:
#
# no indexes (at least, the queries will not be using any indexes);
# using index on datetime only;
# using index on comments (or more accurately, on comments_tsv) only;
# using indexes on both datetime and comments(_tsv)

# %%
def index_or_not(query_fun, year, word, n, has_index_or_not):
    query = query_fun(year, word)

    # run it 50 times
    times = []
    for i in range(n):
        start = time.time()
        with db_eng.begin() as conn:
            conn.execute(sql_text(query)).fetchall()
        end = time.time()
        times.append(end - start)

    #store results
    result1 = {
        f'{word}_{year}': {
            has_index_or_not: {
                'avg': round(sum(times) / len(times), 4),
                'min': round(min(times), 4),
                'max': round(max(times), 4),
                'std': round(np.std(times), 4),
                'count': len(times),
                'timestamp': datetime.now().strftime('%Y-%m-%d-%H:%M:%S')
            }
        }
    }

    # write to json file
    write_perf_data(result1)

    print(f"Finshed: {has_index_or_not} for {word}_{year}.")

# %%
years = [2009, 2010, 2011, 2012, 2013, 2014, 2017, 2020, 2024]
words = ['horrible', 'awesome', 'apartment']

for y in years:
    for w in words:
        # use the index on comments_tsv only with @@
        index_or_not(index_query, y, w, n, 'Index on comments_tsv only')
        # no indexes with 'ilike'
        index_or_not(no_index_query, y, w, n, 'no_index')
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:945, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     944 def do_execute(self, cursor, statement, parameters, context=None):
# --> 945     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "reviews" does not exist
# LINE 3:     FROM reviews r
#                  ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[12], line 7
#       4 for y in years:
#       5     for w in words:
#       6         # use the index on comments_tsv only with @@
# ----> 7         index_or_not(index_query, y, w, n, 'Index on comments_tsv only')
#       8         # no indexes with 'ilike'
#       9         index_or_not(no_index_query, y, w, n, 'no_index')
#
# Cell In[11], line 9, in index_or_not(query_fun, year, word, n, has_index_or_not)
#       7 start = time.time()
#       8 with db_eng.begin() as conn:
# ----> 9     conn.execute(sql_text(query)).fetchall()
#      10 end = time.time()
#      11 times.append(end - start)
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\sql\elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File c:\Users\l2667\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:945, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     944 def do_execute(self, cursor, statement, parameters, context=None):
# --> 945     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "reviews" does not exist
# LINE 3:     FROM reviews r
#                  ^
#
# [SQL:
#     SELECT count(*)
#     FROM reviews r
#     WHERE comments_tsv @@ to_tsquery('horrible')
#       AND datetime >= '2009-01-01'
#       AND datetime <= '2009-12-31';
#     ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# using both indexes with @@
def using_both_index(year, word, n):
    q_create_datetime_index = '''
    CREATE INDEX IF NOT EXISTS datetime_in_reviews
    ON reviews(datetime);
    '''

    with db_eng.connect() as conn:
        conn.execute(sql_text(q_create_datetime_index))
        result_reviews = conn.execute(sql_text("SELECT indexname FROM pg_indexes WHERE tablename = 'reviews';"))
        print()
        print('Indexes:')
        print(result_reviews.all())

    query = index_query(year, word) #with @@ query

    # run it n times
    times = []
    for i in range(n):
        start = time.time()
        with db_eng.begin() as conn:
            conn.execute(sql_text(query)).fetchall()
        end = time.time()
        times.append(end - start)

    #store results
    result2 = {
        f'{word}_{year}': {
            'Index on both datetime_in_reviews and comments_tsv': {
                'avg': round(sum(times) / len(times), 4),
                'min': round(min(times), 4),
                'max': round(max(times), 4),
                'std': round(np.std(times), 4),
                'count': len(times),
                'timestamp': datetime.now().strftime('%Y-%m-%d-%H:%M:%S')
            }
        }
    }

    # write to json file
    write_perf_data(result2)

    print(f"Finshed: index on both for {word}_{year}.")

# %%
# using the index datetime_in_reviews only with 'ilike' query
def only_datetime_index(year, word, n):
    q_create_datetime_index = '''
    CREATE INDEX IF NOT EXISTS datetime_in_reviews
    ON reviews(datetime);
    '''
    
    with db_eng.connect() as conn:
        conn.execute(sql_text(q_create_datetime_index))
        result_reviews = conn.execute(sql_text("SELECT indexname FROM pg_indexes WHERE tablename = 'reviews';"))
        print()
        print('Indexes:')
        print(result_reviews.all())

    query = no_index_query(year, word) #with 'ilike' query

    # run it n times
    times = []
    for i in range(n):
        start = time.time()
        with db_eng.begin() as conn:
            conn.execute(sql_text(query)).fetchall()
        end = time.time()
        times.append(end - start)

    #store results
    result3 = {
        f'{word}_{year}': {
            'Index datetime_in_reviews only': {
                'avg': round(sum(times) / len(times), 4),
                'min': round(min(times), 4),
                'max': round(max(times), 4),
                'std': round(np.std(times), 4),
                'count': len(times),
                'timestamp': datetime.now().strftime('%Y-%m-%d-%H:%M:%S')
            }
        }
    }

    # write to json file
    write_perf_data(result3)

    print(f"Finshed: only datetime index for {word}_{year}.")

# %%
for y in years:
    for w in words:
        using_both_index(y, w, n)
        only_datetime_index(y, w, n)
# Out:
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2009.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2009.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2009.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2009.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2009.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2009.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2010.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2010.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2010.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2010.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2010.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2010.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2011.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2011.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2011.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2011.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2011.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2011.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2012.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2012.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2012.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2012.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2012.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2012.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2013.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2013.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2013.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2013.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2013.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2013.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2014.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2014.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2014.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2014.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2014.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2014.
#
# Indexes:
# [('datetime_in_reviews',), ('comments_tsv_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2017.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2017.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2017.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2017.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2017.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2017.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2020.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2020.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2020.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2020.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2020.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2020.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for horrible_2024.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for horrible_2024.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for awesome_2024.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for awesome_2024.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: index on both for apartment_2024.
#
# Indexes:
# [('comments_tsv_in_reviews',), ('datetime_in_reviews',)]
# wrote in file successfully
# Finshed: only datetime index for apartment_2024.
